# %%
# %matplotlib inline
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import cross_validate
from sklearn import svm
from inforet_package.preprocessing import *

from gensim.models import KeyedVectors
from nltk.tokenize import word_tokenize

#from sklearn.model_selection import train_test_split
#from sklearn import svm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#loading data
EMBEDDINGS = '../data/embeddings/GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'
df = pd.read_csv("../data/train.csv")

embeddings_index = KeyedVectors.load_word2vec_format(EMBEDDINGS, binary=True)

# %%
def print_datasets_info(df):
    print("{} rows loaded...".format(df.shape[0]))
    print("columns are: {}".format(list(df.columns)))
    print("{0:.2f}% of sincere questions".format(len(df[df['target'] == 0])*100/df.shape[0]))
    print("{0:.2f}% of insincere questions".format(len(df[df['target'] == 1])*100/df.shape[0]))

reducted_df = df.sample(frac=0.05)
print_datasets_info(reducted_df)
#questions = reducted_df['question_text'].tolist()
# Out:
# 65306 rows loaded...
# columns are: ['qid', 'question_text', 'target']
# 93.91% of sincere questions
# 6.09% of insincere questions

# %%
print("NOT CLEANED COVERAGE: ")
print("Building dictionary...")
vocab_dictionary = build_dictionary(df['question_text'].tolist())
out_of_dict = check_coverage(vocab_dictionary, embeddings_index)
# Out:
# NOT CLEANED COVERAGE:
# Building dictionary...
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2047), HTML(value='')))
# Found embeddings for 22.42% of vocab
# Found embeddings for  74.15% of all text

# %%
vocab_dictionary
# Out:
# {'H': 335973,
#  'o': 5982041,
#  'w': 1359867,
#  ' ': 15416812,
#  'd': 2536343,
#  'i': 5172726,
#  'Q': 25902,
#  'u': 2006942,
#  'e': 8262611,
#  'b': 1026991,
#  'c': 2182249,
#  'n': 4941624,
#  'a': 6170667,
#  't': 6090023,
#  'l': 2775391,
#  's': 4504441,
#  'h': 3515364,
#  'r': 4310239,
#  'p': 1463297,
#  'v': 714218,
#  '1': 101658,
#  '9': 20498,
#  '6': 20285,
#  '0': 107880,
#  '?': 1381192,
#  'D': 147530,
#  'y': 1576610,
#  'g': 1453078,
#  ',': 235096,
#  'W': 761319,
#  'f': 1491363,
#  'm': 1865095,
#  'O': 44181,
#  'G': 69931,
#  'k': 585414,
#  'M': 137704,
#  'C': 214086,
#  'I': 653841,
#  'j': 96881,
#  'z': 58752,
#  'A': 217720,
#  'T': 135920,
#  'P': 111277,
#  '.': 134056,
#  '/': 42137,
#  'F': 50532,
#  'x': 157411,
#  'S': 216609,
#  '3': 32458,
#  'B': 106238,
#  'R': 65351,
#  'X': 7314,
#  'U': 66833,
#  "'": 163763,
#  'E': 100677,
#  'q': 62794,
#  'V': 30712,
#  '2': 77956,
#  '8': 24711,
#  '-': 67094,
#  '(': 56618,
#  'N': 67591,
#  'Y': 15990,
#  ')': 56594,
#  '7': 25697,
#  'J': 50501,
#  '"': 73272,
#  'L': 53377,
#  'K': 43541,
#  '5': 35019,
#  '$': 4242,
#  '=': 4248,
#  '…': 1928,
#  '*': 1275,
#  '4': 25503,
#  '’': 21317,
#  '&': 8413,
#  'é': 834,
#  'Z': 5560,
#  '+': 9839,
#  'á': 158,
#  '′': 13,
#  '[': 2853,
#  'ɾ': 4,
#  '̃': 4,
#  ']': 2859,
#  'ɖ': 5,
#  '%': 6233,
#  ':': 8688,
#  '^': 5018,
#  '\xa0': 242,
#  '\\': 3495,
#  '{': 3121,
#  '}': 3099,
#  'ö': 145,
#  '–': 294,
#  '“': 3871,
#  '”': 3911,
#  '‘': 874,
#  'ऋ': 1,
#  'ॠ': 2,
#  'ऌ': 2,
#  'ॡ': 2,
#  '\u200b': 836,
#  ';': 1465,
#  'ò': 17,
#  '!': 2276,
#  '谢': 6,
#  '六': 1,
#  '佬': 1,
#  'è': 61,
#  'ù': 8,
#  'â': 24,
#  '<': 462,
#  'ğ': 28,
#  '`': 147,
#  'म': 105,
#  'ि': 118,
#  'ल': 104,
#  'ग': 46,
#  'ई': 8,
#  'क': 139,
#  'े': 102,
#  'ज': 49,
#  'ो': 43,
#  'ठ': 10,
#  'ं': 42,
#  'ड': 34,
#  'Ž': 6,
#  'ž': 14,
#  'ó': 93,
#  '®': 21,
#  'ê': 16,
#  'ạ': 5,
#  'ệ': 5,
#  '°': 300,
#  '#': 728,
#  'ص': 6,
#  'و': 37,
#  'ر': 23,
#  'ü': 136,
#  '²': 222,
#  '|': 516,
#  '~': 185,
#  '₹': 227,
#  'ú': 51,
#  '√': 395,
#  '_': 1388,
#  'α': 54,
#  '→': 23,
#  '>': 527,
#  'ū': 40,
#  '—': 118,
#  '£': 253,
#  'ä': 65,
#  '啧': 2,
#  '，': 50,
#  '您': 2,
#  '这': 5,
#  '口': 6,
#  '味': 2,
#  '奇': 2,
#  '特': 1,
#  '也': 2,
#  '就': 3,
#  '罢': 1,
#  '了': 4,
#  '非': 1,
#  '要': 4,
#  '以': 4,
#  '此': 2,
#  '为': 3,
#  '依': 1,
#  '据': 1,
#  '对': 5,
#  '人': 30,
#  '家': 5,
#  '批': 1,
#  '判': 1,
#  '一': 23,
#  '番': 1,
#  '不': 14,
#  '地': 1,
#  '道': 2,
#  '啊': 1,
#  '。': 8,
#  '️': 21,
#  'ø': 17,
#  '´': 130,
#  '×': 303,
#  '@': 233,
#  'í': 117,
#  'ō': 49,
#  'π': 151,
#  '÷': 97,
#  '\ufeff': 23,
#  '？': 103,
#  'ʿ': 4,
#  '€': 114,
#  '有': 9,
#  '毒': 1,
#  '黎': 1,
#  '氏': 1,
#  '玉': 2,
#  '英': 2,
#  'ñ': 66,
#  'ç': 79,
#  '欢': 1,
#  '迎': 1,
#  '入': 3,
#  '坑': 1,
#  'へ': 5,
#  'の': 9,
#  'と': 3,
#  'も': 3,
#  '↑': 4,
#  '∞': 45,
#  'ʻ': 6,
#  '℅': 23,
#  'н': 26,
#  'м': 13,
#  'ѕ': 11,
#  'т': 31,
#  'в': 10,
#  'υ': 8,
#  'ι': 21,
#  '•': 32,
#  'ì': 12,
#  '−': 70,
#  'Е': 4,
#  'е': 39,
#  'л': 15,
#  'я': 12,
#  'д': 19,
#  'у': 6,
#  'р': 16,
#  'а': 31,
#  'к': 16,
#  '新': 2,
#  '年': 1,
#  '快': 1,
#  '乐': 1,
#  '！': 5,
#  '学': 3,
#  '业': 2,
#  '进': 1,
#  '步': 2,
#  '身': 4,
#  '体': 1,
#  '健': 1,
#  '康': 1,
#  '们': 2,
#  '读': 2,
#  '我': 14,
#  '的': 20,
#  '翻': 1,
#  '译': 2,
#  '篇': 1,
#  '章': 1,
#  'ë': 31,
#  'ń': 2,
#  'ل': 49,
#  'ك': 9,
#  'م': 38,
#  'ق': 10,
#  'ا': 76,
#  '∈': 16,
#  '∩': 14,
#  '⊆': 11,
#  'ã': 44,
#  'अ': 15,
#  'न': 158,
#  'ु': 39,
#  'स': 69,
#  '्': 95,
#  'व': 40,
#  'ा': 326,
#  'र': 176,
#  'त': 64,
#  '§': 4,
#  '℃': 11,
#  '標': 1,
#  '點': 2,
#  '符': 1,
#  '號': 1,
#  '\xad': 6,
#  'θ': 53,
#  '±': 6,
#  '≤': 10,
#  'उ': 15,
#  'द': 49,
#  'य': 41,
#  'ब': 50,
#  'ट': 34,
#  '͡': 4,
#  '͜': 6,
#  'ʖ': 2,
#  '⁴': 19,
#  '™': 60,
#  'ć': 24,
#  'ô': 16,
#  'с': 27,
#  'п': 10,
#  'и': 25,
#  'б': 7,
#  'о': 32,
#  'г': 5,
#  '≠': 14,
#  '∂': 1,
#  'आ': 22,
#  'ह': 73,
#  'भ': 18,
#  'ी': 66,
#  '³': 60,
#  'च': 37,
#  '能': 4,
#  '化': 3,
#  '生': 6,
#  '水': 4,
#  '谷': 1,
#  '精': 2,
#  '微': 1,
#  'ฉ': 1,
#  'ั': 5,
#  'น': 8,
#  'จ': 3,
#  'ะ': 7,
#  'ท': 4,
#  'ำ': 3,
#  'ใ': 3,
#  'ห': 4,
#  '้': 7,
#  'ด': 4,
#  'ี': 3,
#  '่': 6,
#  'ส': 1,
#  'ุ': 2,
#  'Π': 5,
#  'प': 66,
#  'ऊ': 4,
#  'Ö': 14,
#  '请': 2,
#  '国': 25,
#  '知': 6,
#  '识': 2,
#  '产': 1,
#  '权': 1,
#  '局': 2,
#  'خ': 5,
#  'ب': 25,
#  'ஜ': 1,
#  'ோ': 1,
#  'ட': 8,
#  'ி': 5,
#  '大': 15,
#  '「': 10,
#  '寧': 1,
#  '可': 6,
#  '錯': 1,
#  '殺': 2,
#  '千': 2,
#  '絕': 1,
#  '放': 2,
#  '過': 2,
#  '」': 10,
#  '之': 5,
#  '勢': 1,
#  'ẽ': 1,
#  '½': 14,
#  '△': 1,
#  'É': 30,
#  'ķ': 1,
#  'ï': 25,
#  '¿': 26,
#  'ł': 12,
#  '북': 2,
#  '한': 6,
#  'ı': 68,
#  'Ь': 1,
#  'Ъ': 1,
#  '\u202a': 11,
#  '¼': 4,
#  '∆': 27,
#  '≥': 8,
#  '⇒': 4,
#  '¬': 7,
#  '∨': 5,
#  'č': 14,
#  'š': 16,
#  '∫': 20,
#  'ḥ': 5,
#  'ā': 50,
#  'ī': 19,
#  'Ñ': 2,
#  'à': 67,
#  '▾': 5,
#  'Ω': 8,
#  '＾': 1,
#  '江': 4,
#  '青': 1,
#  'γ': 11,
#  '鸡': 1,
#  '汤': 1,
#  '文': 11,
#  '粵': 1,
#  '拼': 1,
#  'ý': 4,
#  'µ': 4,
#  '\u202c': 4,
#  'श': 20,
#  'थ': 9,
#  'झ': 6,
#  'ौ': 4,
#  'ू': 17,
#  'ओ': 4,
#  'ĺ': 4,
#  'º': 7,
#  'ष': 10,
#  '♭': 3,
#  '封': 1,
#  '柏': 1,
#  '荣': 1,
#  '़': 37,
#  'ル': 2,
#  'ー': 4,
#  'ジ': 2,
#  'ュ': 1,
#  'İ': 12,
#  '⃗': 2,
#  '̂': 8,
#  'æ': 16,
#  'ɔ': 1,
#  '∑': 7,
#  '\u2061': 2,
#  'র': 15,
#  'ড়': 2,
#  'ঢ়': 1,
#  'સ': 1,
#  'ં': 1,
#  'ઘ': 1,
#  'ર': 1,
#  'ા': 1,
#  'જ': 1,
#  '્': 1,
#  'ય': 1,
#  'ε': 20,
#  'ν': 12,
#  'τ': 19,
#  'σ': 18,
#  'ş': 19,
#  'ś': 3,
#  '配': 1,
#  '信': 2,
#  '開': 1,
#  '始': 1,
#  '日': 8,
#  '商': 2,
#  '品': 2,
#  '発': 1,
#  '売': 1,
#  '分': 3,
#  '子': 11,
#  'Ψ': 3,
#  '创': 1,
#  '意': 4,
#  '梦': 1,
#  '工': 1,
#  '坊': 1,
#  'ک': 7,
#  'پ': 6,
#  'ڤ': 1,
#  '蘭': 1,
#  '花': 1,
#  '羡': 1,
#  '慕': 1,
#  '和': 10,
#  '嫉': 1,
#  '妒': 1,
#  '是': 17,
#  '样': 4,
#  'ן': 2,
#  'Γ': 5,
#  '∪': 10,
#  'φ': 13,
#  'ψ': 6,
#  '⊨': 2,
#  'β': 22,
#  'ै': 30,
#  'ご': 4,
#  'め': 6,
#  'な': 12,
#  'さ': 7,
#  'い': 19,
#  'す': 9,
#  'み': 3,
#  'ま': 10,
#  'せ': 4,
#  'ん': 16,
#  '音': 4,
#  '红': 1,
#  '宝': 2,
#  '书': 2,
#  'س': 12,
#  'ت': 16,
#  'ط': 7,
#  'ي': 29,
#  'ع': 18,
#  'ة': 7,
#  'د': 18,
#  '支': 2,
#  '那': 1,
#  '¹': 11,
#  'マ': 1,
#  'リ': 2,
#  '仲': 1,
#  '直': 1,
#  'り': 1,
#  'し': 14,
#  'た': 10,
#  '主': 3,
#  '席': 1,
#  'þ': 3,
#  'ð': 7,
#  '\u2060': 2,
#  '血': 2,
#  'ě': 5,
#  '∘': 13,
#  '¨': 11,
#  '″': 13,
#  '⅓': 4,
#  'ढ': 8,
#  '漢': 3,
#  '髪': 4,
#  '金': 6,
#  '茶': 1,
#  '訓': 1,
#  '読': 1,
#  '黒': 1,
#  'ř': 9,
#  'あ': 3,
#  'わ': 3,
#  'る': 12,
#  'ɑ': 8,
#  'ː': 6,
#  '胡': 1,
#  '南': 2,
#  '✅': 1,
#  '✓': 5,
#  '수': 3,
#  '능': 1,
#  '（': 9,
#  '广': 1,
#  '电': 1,
#  '总': 2,
#  '）': 10,
#  'κ': 4,
#  'ί': 2,
#  '서': 2,
#  '로': 3,
#  '가': 2,
#  '를': 3,
#  '행': 1,
#  '복': 1,
#  '하': 9,
#  '게': 1,
#  '기': 1,
#  '乡': 4,
#  '故': 1,
#  '∠': 4,
#  'Ó': 4,
#  '«': 6,
#  '»': 6,
#  '爾': 1,
#  '汝': 1,
#  '言': 7,
#  'ح': 12,
#  'ஆ': 3,
#  'ய': 4,
#  '்': 25,
#  'த': 8,
#  'எ': 3,
#  'ழ': 3,
#  'ு': 11,
#  '得': 5,
#  '理': 1,
#  '让': 1,
#  'λ': 17,
#  '∧': 8,
#  '∀': 2,
#  '骂': 1,
#  'å': 18,
#  '،': 13,
#  '＝': 5,
#  '野': 1,
#  '比': 3,
#  'び': 1,
#  '太': 5,
#  'ɦ': 1,
#  'ʏ': 1,
#  'ɨ': 4,
#  'ɛ': 10,
#  'ʀ': 4,
#  'ċ': 4,
#  'օ': 3,
#  'ʍ': 2,
#  'ռ': 2,
#  'ք': 1,
#  'ʋ': 1,
#  '兰': 1,
#  'ϵ': 4,
#  'δ': 15,
#  'Ľ': 1,
#  'ɒ': 1,
#  'î': 8,
#  '後': 1,
#  '宮': 1,
#  '甄': 1,
#  '嬛': 1,
#  '傳': 3,
#  'ᠠ': 1,
#  'ᡳ': 2,
#  '᠌': 1,
#  'ᠰ': 1,
#  'ᠨ': 1,
#  'ᡤ': 1,
#  'ᡠ': 2,
#  'ᡵ': 1,
#  'ṭ': 3,
#  'ế': 3,
#  'ध': 14,
#  'ड़': 4,
#  'ß': 12,
#  '¸': 1,
#  'ч': 5,
#  '☹': 1,
#  'ễ': 4,
#  'ộ': 3,
#  'फ': 11,
#  'μ': 17,
#  '做': 1,
#  '莫': 1,
#  '你': 8,
#  '酱': 1,
#  '紫': 1,
#  'Δ': 18,
#  '내': 1,
#  '제': 1,
#  'ʃ': 1,
#  'ɸ': 4,
#  'ợ': 1,
#  '甲': 1,
#  '骨': 2,
#  '陳': 3,
#  '宗': 2,
#  '陈': 2,
#  '什': 2,
#  '么': 5,
#  '说': 5,
#  'Ō': 8,
#  'ㅜ': 2,
#  'Ο': 1,
#  'ς': 11,
#  'ο': 17,
#  'η': 6,
#  'Σ': 12,
#  'ण': 6,
#  '伊': 1,
#  '藤': 1,
#  '長': 1,
#  '₅': 1,
#  '₆': 2,
#  'ﷺ': 2,
#  '僕': 1,
#  'だ': 6,
#  'け': 3,
#  'が': 5,
#  '街': 1,
#  '◦': 2,
#  '火': 1,
#  '团': 1,
#  '表': 2,
#  '·': 18,
#  'औ': 2,
#  'Á': 12,
#  'छ': 8,
#  'Ś': 5,
#  'ए': 13,
#  '看': 2,
#  '他': 4,
#  '顺': 1,
#  '眼': 1,
#  '中': 17,
#  '華': 2,
#  '民': 17,
#  '國': 4,
#  'ف': 16,
#  'ن': 20,
#  'ḵ': 1,
#  'Č': 4,
#  'П': 1,
#  'ь': 8,
#  'В': 3,
#  'Φ': 4,
#  'ỵ': 1,
#  '許': 1,
#  '自': 3,
#  '東': 2,
#  'Å': 6,
#  '☺': 4,
#  'ℇ': 1,
#  '❤': 4,
#  '♨': 1,
#  '✌': 2,
#  '儿': 1,
#  '臣': 1,
#  '惶': 1,
#  '恐': 1,
#  'っ': 6,
#  '木': 3,
#  'ホ': 1,
#  'ج': 8,
#  '⧼': 1,
#  '⧽': 1,
#  'ম': 5,
#  'হ': 3,
#  'া': 14,
#  'ব': 6,
#  'ি': 10,
#  'শ': 4,
#  '্': 15,
#  'প': 9,
#  'ত': 6,
#  'ন': 9,
#  'য়': 4,
#  'স': 5,
#  'চ': 1,
#  'ছ': 3,
#  'ে': 8,
#  'ষ': 4,
#  'য': 2,
#  '়': 1,
#  'ট': 3,
#  'উ': 2,
#  'থ': 2,
#  'ক': 8,
#  'ῥ': 2,
#  'ζ': 1,
#  'ὤ': 1,
#  'Ü': 9,
#  '教': 2,
#  '官': 1,
#  '국': 4,
#  '고': 5,
#  '등': 1,
#  '학': 1,
#  '교': 1,
#  '는': 3,
#  '몇': 1,
#  '시': 1,
#  '간': 1,
#  '업': 1,
#  '니': 3,
#  '까': 1,
#  'ಸ': 2,
#  '್': 2,
#  'ವ': 1,
#  'ರ': 2,
#  'ಕ': 3,
#  'ಷ': 1,
#  'ಗ': 1,
#  'ಳ': 1,
#  'ು': 2,
#  '本': 8,
#  '語': 6,
#  '上': 4,
#  '手': 4,
#  'で': 5,
#  'ね': 3,
#  'Ἀ': 2,
#  'χ': 5,
#  'ῆ': 1,
#  'ύ': 1,
#  'ኤ': 2,
#  'ል': 2,
#  'ሮ': 2,
#  'ኢ': 2,
#  'የ': 7,
#  'ኝ': 2,
#  'ን': 2,
#  'አ': 2,
#  'ሁ': 2,
#  '台': 3,
#  '湾': 1,
#  '最': 1,
#  '美': 3,
#  '风': 2,
#  '景': 1,
#  'Î': 3,
#  '≡': 9,
#  '皎': 2,
#  '滢': 2,
#  '杨': 1,
#  '\u200e': 6,
#  '∛': 4,
#  '簡': 1,
#  '訊': 1,
#  '短': 1,
#  '送': 3,
#  '發': 1,
#  'お': 3,
#  '早': 3,
#  'う': 4,
#  '朝': 5,
#  'ش': 15,
#  'ه': 17,
#  '饭': 1,
#  '乱': 3,
#  '吃': 4,
#  '话': 1,
#  '讲': 3,
#  'ấ': 1,
#  'ũ': 4,
#  '눈': 1,
#  '치': 1,
#  'ụ': 1,
#  '男': 2,
#  '女': 3,
#  '授': 1,
#  '受': 1,
#  '亲': 1,
#  'ی': 6,
#  'М': 2,
#  'ю': 9,
#  'ʌ': 1,
#  'ʊ': 5,
#  'י': 6,
#  'ה': 4,
#  'ו': 8,
#  'ד': 1,
#  'ת': 7,
#  '好': 6,
#  '心': 3,
#  '没': 4,
#  '报': 2,
#  'Í': 1,
#  'க': 11,
#  'வ': 5,
#  'ா': 6,
#  'ம': 6,
#  '≈': 3,
#  '⁰': 2,
#  '⁷': 1,
#  '攻': 1,
#  '克': 1,
#  'ख': 16,
#  'Ĺ': 1,
#  'ĩ': 3,
#  '禮': 3,
#  '儀': 1,
#  '統': 1,
#  '已': 1,
#  '經': 1,
#  '失': 1,
#  '存': 2,
#  '٨': 2,
#  '八': 2,
#  '‛': 4,
#  '字': 5,
#  '：': 4,
#  '别': 1,
#  '高': 3,
#  '兴': 2,
#  '还': 1,
#  '几': 1,
#  '个': 5,
#  '条': 1,
#  '件': 1,
#  '呢': 3,
#  'ə': 9,
#  'ਨ': 2,
#  'ਾ': 3,
#  'ਮ': 2,
#  'ੁ': 1,
#  '觀': 2,
#  '《': 2,
#  '》': 2,
#  'ﬁ': 3,
#  'て': 15,
#  '„': 4,
#  'Ā': 3,
#  '宋': 2,
#  '楚': 1,
#  '瑜': 1,
#  '孫': 1,
#  '瀛': 1,
#  '枚': 1,
#  '无': 3,
#  '挑': 1,
#  '剔': 1,
#  '¾': 4,
#  'Я': 2,
#  'х': 1,
#  'О': 2,
#  'з': 4,
#  '聖': 1,
#  'Ş': 3,
#  '部': 2,
#  '頭': 1,
#  '合': 3,
#  '約': 1,
#  'ρ': 14,
#  '⌚': 1,
#  '⟨': 1,
#  '⟩': 3,
#  '∖': 1,
#  '˂': 1,
#  '油': 1,
#  '腻': 1,
#  '邋': 1,
#  '遢': 1,
#  'ٌ': 1,
#  'Ä': 1,
#  '射': 1,
#  '籍': 1,
#  '贯': 1,
#  'ό': 2,
#  'È': 4,
#  '老': 3,
#  '常': 2,
#  '谈': 1,
#  'ⁿ': 11,
#  '⅔': 3,
#  'న': 6,
#  'ీ': 1,
#  'క': 3,
#  'ె': 3,
#  'ం': 3,
#  'ద': 2,
#  'ు': 5,
#  'ా': 3,
#  'గ': 1,
#  'ర': 2,
#  'ి': 6,
#  'చ': 3,
#  '族': 3,
#  '伟': 1,
#  '复': 1,
#  '平': 1,
#  '天': 7,
#  '下': 4,
#  '悠': 6,
#  '堵': 1,
#  '阻': 1,
#  '≅': 1,
#  'ϕ': 3,
#  '‑': 4,
#  '愛': 1,
#  '\x7f': 5,
#  '过': 3,
#  '会': 3,
#  'ả': 3,
#  '￼': 3,
#  'ֿ': 2,
#  'か': 13,
#  'く': 8,
#  'れ': 5,
#  'ő': 5,
#  '－': 1,
#  'ș': 9,
#  '俄': 2,
#  '罗': 6,
#  '斯': 2,
#  '茹': 1,
#  '西': 4,
#  '亚': 3,
#  '싱': 1,
#  '관': 1,
#  '없': 2,
#  '어': 6,
#  '나': 2,
#  '이': 9,
#  '키': 1,
#  '夢': 2,
#  '彩': 1,
#  '蛋': 2,
#  '︠': 1,
#  '︡': 1,
#  '鰹': 1,
#  '節': 1,
#  '狐': 1,
#  '狸': 1,
#  '鳳': 1,
#  '凰': 1,
#  '露': 1,
#  'Ź': 1,
#  'Ż': 3,
#  'ἰ': 1,
#  'ή': 1,
#  'Š': 5,
#  '＞': 1,
#  ...}

# %%
cleaned_questions = cleaning_questions(df)
# Out:
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))

# %%
vocab_dictionary = build_dictionary(cleaned_questions)
out_of_dict = check_coverage(vocab_dictionary, embeddings_index)
# Out:
# HBox(children=(IntProgress(value=0, max=1306122), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=238749), HTML(value='')))
# Found embeddings for 61.06% of vocab
# Found embeddings for  99.00% of all text

# %%
vocab_dictionary
# Out:
# {'How': 263116,
#  'did': 34677,
#  'Quebec': 161,
#  'nationalists': 131,
#  'see': 9562,
#  'their': 34879,
#  'province': 170,
#  'as': 55734,
#  'nation': 1423,
#  'in': 367649,
#  'the': 655277,
#  '#': 384385,
#  's': 73604,
#  'Do': 40149,
#  'you': 199472,
#  'have': 85523,
#  'an': 67003,
#  'adopted': 363,
#  'dog': 3490,
#  'how': 26994,
#  'would': 51616,
#  'encourage': 392,
#  'people': 55501,
#  'adopt': 485,
#  'not': 51021,
#  'shop': 869,
#  'Why': 145161,
#  'does': 64106,
#  'velocity': 810,
#  'affect': 4420,
#  'time': 23785,
#  'Does': 23211,
#  'space': 3427,
#  'geometry': 219,
#  'Otto': 55,
#  'von': 87,
#  'Guericke': 4,
#  'used': 13173,
#  'Magdeburg': 7,
#  'hemispheres': 15,
#  'Can': 53062,
#  'I': 325976,
#  'convert': 1557,
#  'montra': 3,
#  'helicon': 1,
#  'D': 1325,
#  'mountain': 346,
#  'bike': 1072,
#  'by': 42288,
#  'just': 16204,
#  'changing': 1141,
#  'tyres': 92,
#  'Is': 108974,
#  'Gaza': 105,
#  'slowly': 361,
#  'becoming': 2271,
#  'Auschwitz': 29,
#  'Dachau': 4,
#  'or': 92349,
#  'Treblinka': 1,
#  'for': 201932,
#  'Palestinians': 595,
#  'Quora': 15821,
#  'automatically': 610,
#  'ban': 990,
#  'conservative': 1039,
#  'opinions': 646,
#  'when': 48213,
#  'reported': 311,
#  'but': 26702,
#  'do': 212975,
#  'same': 11251,
#  'liberal': 1373,
#  'views': 1943,
#  'it': 139491,
#  'crazy': 821,
#  'if': 64041,
#  'wash': 501,
#  'wipe': 204,
#  'my': 104306,
#  'groceries': 59,
#  'off': 7014,
#  'Germs': 2,
#  'are': 213734,
#  'everywhere': 381,
#  'there': 52850,
#  'such': 7457,
#  'thing': 8442,
#  'dressing': 167,
#  'moderately': 28,
#  'so': 37615,
#  'is': 333969,
#  'that': 107173,
#  'different': 12050,
#  'than': 23934,
#  'modestly': 17,
#  'me': 35971,
#  'ever': 17928,
#  'been': 13832,
#  'this': 26833,
#  'phase': 697,
#  'wherein': 44,
#  'became': 1239,
#  'ignorant': 469,
#  'once': 2477,
#  'loved': 975,
#  'completely': 1945,
#  'disregarding': 21,
#  'feelings': 1603,
#  'lives': 1575,
#  'get': 62540,
#  'something': 7920,
#  'go': 14647,
#  'your': 67296,
#  'way': 20709,
#  'feel': 16201,
#  'temporarily': 156,
#  'at': 46384,
#  'ease': 168,
#  'things': 10749,
#  'change': 9237,
#  'What': 430844,
#  'can': 133008,
#  'say': 9880,
#  'about': 45025,
#  'feminism': 551,
#  'were': 16903,
#  'Calgary': 54,
#  'Flames': 13,
#  'founded': 469,
#  'dumbest': 153,
#  'yet': 2568,
#  'possibly': 592,
#  'true': 7472,
#  'explanation': 586,
#  'Trump': 13971,
#  'being': 18741,
#  'elected': 512,
#  'we': 38648,
#  'use': 21722,
#  'our': 11213,
#  'external': 608,
#  'hard': 5379,
#  'disk': 249,
#  'OS': 578,
#  'well': 5235,
#  'data': 5709,
#  'storagewill': 1,
#  'be': 91584,
#  'affected': 1026,
#  'am': 18605,
#  'living': 5075,
#  'home': 6253,
#  'no': 14199,
#  'boyfriend': 3512,
#  'love': 10894,
#  'own': 8467,
#  'progress': 480,
#  'situation': 1736,
#  'know': 20092,
#  'Bram': 11,
#  'Fischer': 23,
#  'Rivonia': 1,
#  'Trial': 19,
#  'difficult': 2847,
#  'find': 17188,
#  'good': 38227,
#  'instructor': 107,
#  'take': 18504,
#  'class': 7112,
#  'near': 1972,
#  'Have': 7227,
#  'licked': 62,
#  'skin': 2737,
#  'corpse': 46,
#  'think': 25993,
#  'Amazon': 2634,
#  'will': 35957,
#  'house': 3910,
#  'approach': 1406,
#  'manufacturing': 992,
#  'similar': 3095,
#  'Tesla': 668,
#  'Space': 310,
#  'X': 1274,
#  'business': 10577,
#  'models': 728,
#  'many': 24156,
#  'baronies': 2,
#  'might': 2059,
#  'exist': 2983,
#  'within': 2306,
#  'county': 177,
#  'palatine': 1,
#  'whether': 1328,
#  'girl': 8779,
#  'had': 12237,
#  'done': 6062,
#  'sex': 9074,
#  'before': 10854,
#  'with': 94474,
#  'become': 16971,
#  'fast': 2415,
#  'learner': 119,
#  'both': 5007,
#  'professional': 2285,
#  'career': 6425,
#  'personal': 2869,
#  'life': 22158,
#  'Has': 5849,
#  'United': 4468,
#  'States': 3779,
#  'largest': 1035,
#  'dictatorship': 190,
#  'world': 15113,
#  'strangest': 313,
#  'phenomenon': 210,
#  'witnessed': 270,
#  'generated': 267,
#  'area': 2623,
#  'electronics': 901,
#  'has': 25974,
#  'terms': 2871,
#  'modern': 2927,
#  'physics': 3132,
#  'Should': 16615,
#  'leave': 3277,
#  'friends': 6025,
#  'new': 10918,
#  'ones': 1987,
#  'make': 28157,
#  'Alexa': 159,
#  'trigger': 223,
#  'events': 1640,
#  'browser': 400,
#  'haven': 1141,
#  't': 46949,
#  'two': 8353,
#  'democracies': 55,
#  'never': 6681,
#  'went': 1434,
#  'full': 3849,
#  'fledged': 14,
#  'war': 4498,
#  'stops': 415,
#  'them': 18314,
#  'top': 5510,
#  'CBSE': 1911,
#  '6': 3493,
#  'months': 4008,
#  'should': 48052,
#  'visiting': 879,
#  'Mcleodganj': 4,
#  'doing': 7359,
#  'Triund': 2,
#  'trek': 64,
#  'military': 3295,
#  'submarines': 95,
#  'reduce': 1879,
#  'noise': 484,
#  'achieve': 1236,
#  'stealth': 85,
#  'Which': 47352,
#  'babies': 674,
#  'more': 26581,
#  'sweeter': 17,
#  'parents': 5889,
#  'Dark': 260,
#  'light': 3818,
#  'remove': 2372,
#  'black': 6407,
#  'heads': 302,
#  'which': 18446,
#  'all': 25585,
#  'over': 11445,
#  'nose': 799,
#  'If': 34773,
#  'lightsabers': 13,
#  'created': 2044,
#  'individual': 1228,
#  'wielders': 2,
#  'each': 5434,
#  'saber': 26,
#  'unique': 1082,
#  'powers': 634,
#  'abilities': 307,
#  'anyone': 8771,
#  'still': 12174,
#  'using': 9504,
#  'Visual': 125,
#  'Basic': 78,
#  'worth': 4262,
#  'learning': 5596,
#  'Would': 9869,
#  'jobs': 4393,
#  'programmers': 334,
#  'Sykes': 13,
#  'Enterprises': 29,
#  'any': 38788,
#  'clear': 1743,
#  'relations': 794,
#  'between': 24137,
#  'number': 7246,
#  'nodes': 148,
#  'DOFs': 1,
#  'computational': 131,
#  'performances': 65,
#  'requirements': 1120,
#  'FEA': 13,
#  'CFD': 36,
#  'analyses': 26,
#  'ANSYS': 16,
#  'solutions': 684,
#  'particular': 1088,
#  'package': 1020,
#  'ISC': 388,
#  'since': 3781,
#  'May': 727,
#  'don': 15485,
#  'updated': 225,
#  'great': 4046,
#  'wit': 32,
#  'mean': 13551,
#  'In': 10252,
#  'experience': 7483,
#  'working': 5993,
#  'Realtors': 3,
#  'what': 38150,
#  'wish': 1538,
#  'better': 15988,
#  'charge': 1982,
#  'contact': 2164,
#  'public': 3875,
#  'school': 10659,
#  'teachers': 1142,
#  'vacation': 631,
#  'whenever': 584,
#  'they': 42682,
#  'ask': 5183,
#  'role': 3212,
#  'technology': 3462,
#  'resource': 385,
#  'opt': 628,
#  'Jaypee': 37,
#  'University': 5394,
#  'Guna': 10,
#  'mechanical': 3091,
#  'engineering': 8943,
#  'Where': 19377,
#  'download': 2532,
#  'Microsoft': 1152,
#  'Word': 223,
#  'Windows': 1363,
#  'Hungarian': 101,
#  'need': 13021,
#  'buying': 1817,
#  'car': 5653,
#  'South': 3441,
#  'Africa': 1996,
#  'American': 7616,
#  'As': 4709,
#  'someone': 22360,
#  'who': 29579,
#  'didn': 3282,
#  'enjoy': 1651,
#  'Harry': 1454,
#  'Potter': 952,
#  'Order': 181,
#  'Phoenix': 161,
#  'movie': 5256,
#  'least': 2248,
#  'book': 9343,
#  'writing': 4505,
#  'style': 2104,
#  'Resist': 2,
#  'Prince': 460,
#  'Charming': 8,
#  'Linda': 52,
#  'Kage': 9,
#  'My': 8263,
#  'mother': 2768,
#  'expects': 51,
#  'memorize': 171,
#  'her': 13955,
#  'usernames': 19,
#  'passwords': 109,
#  'responsible': 1146,
#  'going': 8092,
#  'college': 9628,
#  'one': 33243,
#  'year': 15941,
#  'kid': 1054,
#  'fooled': 80,
#  'into': 16032,
#  'thinking': 2408,
#  'germs': 61,
#  'kill': 3274,
#  'him': 8996,
#  'he': 20560,
#  'bubble': 303,
#  'most': 28879,
#  'his': 17517,
#  'then': 8819,
#  'decides': 242,
#  'travel': 3924,
#  'portable': 163,
#  'germ': 19,
#  'free': 7720,
#  'computer': 5964,
#  'science': 6762,
#  'student': 8602,
#  'buy': 8619,
#  'final': 1409,
#  'project': 2658,
#  'from': 68539,
#  'outside': 2161,
#  'rather': 2888,
#  'education': 3538,
#  'system': 7021,
#  'really': 11665,
#  'week': 2478,
#  'some': 53917,
#  'ways': 7104,
#  'shorten': 52,
#  'period': 2854,
#  'risks': 981,
#  'calead': 1,
#  'leap': 83,
#  'days': 5645,
#  'rid': 2631,
#  'spleen': 24,
#  'enlargement': 25,
#  'machine': 2576,
#  'techniques': 1446,
#  'extract': 254,
#  'metadata': 20,
#  'font': 241,
#  'color': 2781,
#  'size': 2379,
#  'indentation': 3,
#  'alignment': 57,
#  'word': 3865,
#  'document': 501,
#  'docx': 6,
#  'file': 1826,
#  'integrated': 339,
#  'web': 2945,
#  'application': 2843,
#  'work': 18772,
#  'girls': 6576,
#  'Hitch': 3,
#  'Will': 14697,
#  'Smith': 380,
#  'asks': 624,
#  'dance': 670,
#  'too': 6469,
#  'much': 23386,
#  'India': 32729,
#  'Act': 535,
#  'was': 37286,
#  'special': 1958,
#  'Are': 29254,
#  'sports': 1450,
#  'like': 48900,
#  'DNA': 1012,
#  'RNA': 95,
#  'compare': 1556,
#  'contrast': 204,
#  'Someone': 320,
#  'breaks': 314,
#  'shoot': 645,
#  'armed': 408,
#  'only': 13930,
#  'knife': 327,
#  'happens': 5623,
#  'now': 10224,
#  'write': 6052,
#  'biography': 1265,
#  'Gianni': 6,
#  'Versace': 9,
#  'extroverted': 60,
#  'faster': 1410,
#  'processing': 635,
#  'expelling': 18,
#  'information': 2875,
#  'introverts': 217,
#  'recognized': 302,
#  'place': 6226,
#  'very': 7202,
#  'far': 2455,
#  'price': 2716,
#  'comparison': 382,
#  'websites': 2088,
#  'financial': 2039,
#  'services': 2626,
#  'ragging': 70,
#  'happen': 8420,
#  'NIFT': 361,
#  'Bangalore': 2885,
#  'bad': 9549,
#  'reviews': 515,
#  'Bahubali': 84,
#  '2': 10240,
#  'on': 93684,
#  'IMDb': 19,
#  'swallowing': 88,
#  'Listerine': 11,
#  'dangerous': 1548,
#  'theories': 605,
#  'critical': 559,
#  'biggest': 2706,
#  'problems': 3563,
#  'questions': 7430,
#  'doubts': 109,
#  'come': 7466,
#  'across': 1265,
#  'trying': 2801,
#  'choose': 4638,
#  'paint': 629,
#  'room': 1991,
#  'cheap': 1468,
#  'flights': 392,
#  'Edinburgh': 92,
#  'China': 7965,
#  'chick': 47,
#  'send': 2327,
#  'large': 2323,
#  'picture': 1342,
#  'files': 940,
#  'through': 7823,
#  'email': 1992,
#  'doesn': 5873,
#  'eBay': 359,
#  'allow': 2151,
#  'sale': 578,
#  'WWII': 598,
#  'purple': 176,
#  'heart': 2006,
#  'medals': 48,
#  'even': 10294,
#  'though': 2893,
#  'categories': 206,
#  'specifically': 678,
#  'characteristics': 2102,
#  'define': 846,
#  'isovolumetric': 1,
#  'relaxation': 67,
#  'cybersecurity': 60,
#  'overseas': 448,
#  'developer': 2071,
#  'refer': 710,
#  'W3C': 4,
#  'standard': 1588,
#  'practice': 1969,
#  'internet': 2565,
#  'problem': 3860,
#  'rely': 207,
#  'everything': 2999,
#  'ITC': 40,
#  'charges': 785,
#  'levied': 27,
#  'banks': 963,
#  'Muhammed': 32,
#  'provided': 674,
#  'food': 5771,
#  'testing': 1041,
#  'lab': 355,
#  'certified': 326,
#  'ok': 1459,
#  'solo': 336,
#  'whole': 1928,
#  'pretend': 352,
#  'exists': 660,
#  'unwanted': 193,
#  'owner': 740,
#  'current': 4462,
#  'YouTube': 3528,
#  'account': 5873,
#  'The': 10556,
#  'original': 1432,
#  'Owner': 9,
#  'let': 2971,
#  'access': 1505,
#  'anything': 4702,
#  'Archer': 28,
#  'characters': 1517,
#  'animated': 352,
#  'based': 3981,
#  'celebrities': 540,
#  'best': 62445,
#  'propose': 266,
#  'without': 16465,
#  'annoying': 622,
#  'million': 1298,
#  'solar': 1330,
#  'power': 5120,
#  'recommended': 672,
#  '2D': 170,
#  'game': 4003,
#  'engines': 448,
#  'beginning': 667,
#  'Python': 871,
#  'programmer': 687,
#  'teleological': 3,
#  'pantheism': 6,
#  'aircraft': 766,
#  'propulsionMS': 1,
#  'countries': 8121,
#  'freedom': 1167,
#  'speech': 1376,
#  'par': 110,
#  'US': 15530,
#  'lead': 1730,
#  'Red': 463,
#  'Terror': 34,
#  'Ethiopia': 111,
#  'pen': 440,
#  'low': 3680,
#  'cost': 5144,
#  'sorts': 87,
#  'trust': 1454,
#  'Facebook': 4983,
#  'page': 1612,
#  'its': 10718,
#  'website': 5915,
#  'improve': 3943,
#  'piano': 519,
#  'skill': 719,
#  'keep': 6790,
#  'practicing': 298,
#  'pieces': 414,
#  'effective': 2968,
#  'wear': 3294,
#  'insulin': 112,
#  'pump': 418,
#  'lot': 3909,
#  'Nick': 90,
#  'Jonas': 29,
#  'wears': 162,
#  'dated': 266,
#  'Selena': 51,
#  'Gomez': 39,
#  'difference': 12365,
#  'several': 794,
#  'zeros': 40,
#  'missing': 631,
#  'bank': 3479,
#  'Turkey': 1065,
#  'seperated': 26,
#  'give': 10147,
#  'land': 1997,
#  'Kurds': 164,
#  'because': 9340,
#  'foreign': 2724,
#  'USA': 5779,
#  'future': 6010,
#  'R': 1039,
#  'sq': 94,
#  'cos': 179,
#  '1': 8667,
#  'r': 435,
#  'equals': 125,
#  'Who': 22521,
#  'sings': 37,
#  'song': 2638,
#  'head': 2191,
#  'Chronicled': 9,
#  'replace': 1165,
#  'supply': 1002,
#  'Chain': 53,
#  'solve': 1976,
#  'equation…': 2,
#  'Sinat': 2,
#  'bt0': 1,
#  'demerits': 111,
#  'excellence': 40,
#  'academic': 1011,
#  'pursuits': 13,
#  'Indians': 4440,
#  'Melbourne': 267,
#  'Australia': 2958,
#  'physicists': 146,
#  'mathematicians': 149,
#  'scientists': 861,
#  'philosophers': 156,
#  'David': 649,
#  'Deutsch': 13,
#  'Constructor': 2,
#  'Theory': 232,
#  'old': 11363,
#  'scriptures': 100,
#  'eastern': 195,
#  'cultures': 632,
#  'appear': 1401,
#  'lost': 2514,
#  'culture': 3264,
#  'IQ': 1947,
#  'hate': 5247,
#  'numbers': 1924,
#  'up': 18873,
#  'mind': 3407,
#  'habits': 741,
#  'procrastination': 147,
#  'Was': 4354,
#  'relationship': 6344,
#  'Napoleon': 165,
#  'Ali': 319,
#  'Pasha': 10,
#  'Tepelene': 1,
#  'presynaptic': 1,
#  'neurons': 136,
#  'found': 3833,
#  'narcissist': 1582,
#  'punish': 285,
#  'child': 4966,
#  'goes': 1320,
#  'back': 9343,
#  'start': 13109,
#  'freelancing': 194,
#  'after': 28914,
#  'finishing': 179,
#  'Udacity': 91,
#  'Android': 3689,
#  'basic': 2106,
#  'nanodegree': 19,
#  'reason': 4327,
#  'why': 18550,
#  'Bitcoin': 986,
#  'songs': 1867,
#  'long': 11577,
#  'journey': 394,
#  'blacks': 621,
#  'support': 4309,
#  'choice': 1659,
#  'mandatory': 474,
#  'sentencing': 25,
#  'criminals': 441,
#  'vote': 1334,
#  'Republican': 672,
#  'added': 800,
#  'thrice': 51,
#  'rational': 349,
#  '8': 2402,
#  '9': 2048,
#  '4': 5455,
#  '7': 2808,
#  'four': 1167,
#  'movement': 980,
#  'symphony': 33,
#  'typically': 461,
#  'form': 4126,
#  'second': 2759,
#  'various': 1161,
#  'stock': 2450,
#  'exchanges': 160,
#  'gay': 3014,
#  'boy': 2207,
#  'cousin': 439,
#  'He': 2089,
#  'sexy': 316,
#  'dont': 3123,
#  'hot': 1497,
#  'want': 18684,
#  'di': 81,
#  'races': 426,
#  'smallest': 420,
#  'penis': 1375,
#  'Computer': 1073,
#  'Architecture': 128,
#  'Microarchitecture': 1,
#  'Instruction': 8,
#  'set': 2800,
#  'ArchitectureISA': 1,
#  'iPhone': 2641,
#  'users': 1315,
#  'psychologically': 128,
#  'trapped': 189,
#  'brand': 1555,
#  'naming': 134,
#  'avoiding': 168,
#  'complain': 511,
#  'reasonable': 562,
#  'features': 1451,
#  'battery': 1338,
#  'performance': 1372,
#  'lacks': 102,
#  'while': 11361,
#  'other': 22855,
#  'flagship': 32,
#  'semester': 746,
#  'Ontario': 244,
#  'females': 688,
#  'penises': 116,
#  'ugly': 1004,
#  'add': 2244,
#  'flour': 168,
#  'homemade': 407,
#  'chili': 50,
#  'advice': 2996,
#  'wishes': 224,
#  'accomplish': 234,
#  'overcome': 1648,
#  'extreme': 647,
#  'fear': 1864,
#  'insects': 234,
#  'bugs': 247,
#  'examples': 4842,
#  'durable': 115,
#  'gloves': 130,
#  'cars': 1717,
#  'move': 3946,
#  'miles': 463,
#  'towards': 2726,
#  'oppostie': 1,
#  'direction': 762,
#  'distance': 1841,
#  'apps': 2268,
#  'given': 4116,
#  'day': 9594,
#  'maximum': 1310,
#  'headers': 13,
#  'dataset': 117,
#  'noticed': 518,
#  'print': 580,
#  'first': 12537,
#  'anyway': 505,
#  'marry': 2012,
#  'woman': 5058,
#  'Green': 386,
#  'Card': 173,
#  'companies': 5395,
#  'look': 7662,
#  'recruiting': 145,
#  'expat': 105,
#  'nationality': 193,
#  'candidate': 979,
#  'play': 4724,
#  'huge': 1057,
#  'transcranial': 2,
#  'magnetic': 755,
#  'stimulation': 55,
#  'TMS': 13,
#  'increase': 3648,
#  'cognitive': 367,
#  'But': 1132,
#  'George': 782,
#  'Washington': 599,
#  'slaves': 478,
#  'happened': 3507,
#  'Revolutionary': 68,
#  'War': 2457,
#  'policy': 1743,
#  'embassy': 191,
#  'deny': 494,
#  'citizen': 1252,
#  'entry': 1006,
#  'party': 2502,
#  'test': 4769,
#  'energy': 3868,
#  'meter': 287,
#  'periodically': 31,
#  'stationery': 28,
#  'office': 2027,
#  'vs': 2464,
#  'regular': 1354,
#  'genuine': 623,
#  'aviation': 212,
#  'nonprofit': 45,
#  'organizations': 801,
#  'treat': 2751,
#  'employees': 1350,
#  'badly': 534,
#  'procedure': 1773,
#  'invest': 2563,
#  'mutual': 913,
#  'fund': 1117,
#  'osn': 1,
#  'aesthetically': 31,
#  'pleasing': 56,
#  'shade': 100,
#  'green': 1389,
#  'wise': 942,
#  'MCom': 23,
#  'Calcutta': 150,
#  'preparing': 1234,
#  'CAT': 1081,
#  'politician': 479,
#  'leech': 14,
#  'sponsor': 278,
#  'regime': 353,
#  'North': 3836,
#  'Korea': 3036,
#  'Europeans': 992,
#  're': 4563,
#  'superior': 749,
#  'race': 1793,
#  'fact': 2065,
#  'took': 1296,
#  'years': 13848,
#  'until': 1492,
#  'mid': 570,
#  'th': 6197,
#  'century': 1127,
#  'surpass': 100,
#  'economy': 2033,
#  'cytoplasm': 17,
#  'built': 1045,
#  'inside': 1969,
#  'lip': 262,
#  'm': 14375,
#  'creating': 1027,
#  'app': 5612,
#  'multiple': 1786,
#  'programming': 3488,
#  'languages': 2141,
#  'IDE': 88,
#  'neighborhoods': 643,
#  'Chuncheon': 3,
#  'CPSS': 9,
#  'PABT': 7,
#  '4AFSB': 1,
#  'Varanasi': 123,
#  'wrongfully': 23,
#  'jumped': 68,
#  'conclusions': 80,
#  'troubleshooting': 27,
#  'Hewlett': 13,
#  'Packard': 12,
#  'printer': 270,
#  'Isn': 1235,
#  'unfair': 278,
#  'men': 9269,
#  'duty': 457,
#  'NSF': 12,
#  'spinoff': 7,
#  'NSFnet': 1,
#  'helped': 650,
#  'Sun': 394,
#  'Microsystem': 2,
#  'tourist': 738,
#  'known': 4607,
#  'drastically': 110,
#  'changed': 2079,
#  'university': 4135,
#  'Louisville': 18,
#  'listed': 263,
#  'QS': 17,
#  'ranking': 445,
#  'Did': 7591,
#  'Julius': 106,
#  'Caesar': 130,
#  'bring': 1965,
#  'tyrannosaurus': 4,
#  'rex': 15,
#  'campaigns': 187,
#  'frighten': 15,
#  'Celts': 15,
#  'submission': 129,
#  'mercury': 180,
#  'debilitated': 33,
#  'dasa': 15,
#  'Simha': 3,
#  'lagna': 47,
#  'drivers': 579,
#  'Globalisation': 4,
#  'high': 8655,
#  'emotional': 1099,
#  'intelligence': 1832,
#  'womens': 140,
#  'mainstream': 365,
#  'fashions': 5,
#  'compared': 2768,
#  'mens': 111,
#  'cause': 4486,
#  'force': 2626,
#  'magnet': 265,
#  'Nike': 224,
#  'football': 1633,
#  'towels': 44,
#  'manufactured': 500,
#  'win': 4644,
#  'Anizara': 1,
#  'Powered': 5,
#  'Up': 125,
#  'Dragon': 319,
#  'Ball': 276,
#  'Super': 454,
#  'anime': 1613,
#  'episode': 685,
#  'Mystic': 13,
#  'Gohan': 51,
#  '4G': 303,
#  'phone': 5939,
#  'fault': 424,
#  'teen': 694,
#  'daughter': 1628,
#  'social': 6420,
#  'anxiety': 1766,
#  'Sunil': 32,
#  'Raju': 5,
#  ...}

# %%
tfidf_vocab, TfIdfMatrix, idf_dict = idf_dictionary_builder(cleaned_questions)

# %%
insincere_questions = df[df['target'] == 1]
insincere_cleaned_questions = cleaning_questions(insincere_questions)
insincere_vocab_dictionary = build_dictionary(insincere_cleaned_questions)
# Out:
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=80810), HTML(value='')))

# %%
def get_specificity(vocab_corpus_A, vocab_corpus_B):
    total_A = sum([v for v in vocab_corpus_A.values()])
    total_B = sum([v for v in vocab_corpus_B.values()])
    freqA = dict((key, value/total_A) for key, value in vocab_corpus_A.items())
    freqB = dict((key, value/total_B) for key, value in vocab_corpus_B.items())
    spec = {}
    for token, f in freqB.items():
        spec[token] = (f - freqA[token]) / math.sqrt(freqA[token])
    return spec
        
spec = get_specificity(vocab_dictionary, insincere_vocab_dictionary)

# %%
sorted(spec.items(), key=operator.itemgetter(1))[::-1]
# Out:
# [('Why', 0.16559954902282073),
#  ('Muslims', 0.13107139302346155),
#  ('Trump', 0.12860782688272374),
#  ('women', 0.1259173645863908),
#  ('they', 0.11874143478196796),
#  ('Americans', 0.10514714651610678),
#  ('men', 0.10437643890186349),
#  ('people', 0.10383667258280138),
#  ('liberals', 0.10307299110164787),
#  ('white', 0.10206153057081462),
#  ('Indians', 0.0965714811006675),
#  ('so', 0.09397992627496193),
#  ('their', 0.08900792758357925),
#  ('Jews', 0.07979166765324631),
#  ('black', 0.07908314350338902),
#  ('Muslim', 0.07907828708600269),
#  ('hate', 0.07436623193177108),
#  ('Democrats', 0.07380131671670201),
#  ('girls', 0.07169180156432131),
#  ('Hindus', 0.07037958275742844),
#  ('Obama', 0.06903564965181039),
#  ('racist', 0.06832736552700674),
#  ('that', 0.0676469291508543),
#  ('Christians', 0.06761547994755299),
#  ('gay', 0.0663272778045591),
#  ('t', 0.06198352150396479),
#  ('Chinese', 0.060653228578266494),
#  ('Donald', 0.059531578091839746),
#  ('stupid', 0.058588432484150875),
#  ('Hillary', 0.058214314527994596),
#  ('sex', 0.0578967971563428),
#  ('atheists', 0.055262004413795224),
#  ('supporters', 0.05454603950227076),
#  ('blacks', 0.053464315373744936),
#  ('rape', 0.05257626577192452),
#  ('Indian', 0.052029075754665935),
#  ('feminists', 0.05157969506629676),
#  ('conservatives', 0.05088218214153168),
#  ('them', 0.04967663500022392),
#  ('Quora', 0.04966667354449823),
#  ('Clinton', 0.04913873403388511),
#  ('Islam', 0.04878471735258342),
#  ('Modi', 0.04874174321449883),
#  ('against', 0.04819821464946605),
#  ('because', 0.04819046011338638),
#  ('Israel', 0.04751741123184089),
#  ('realize', 0.046773891782703886),
#  ('themselves', 0.04594052241353264),
#  ('all', 0.0457449701884761),
#  ('why', 0.04502304570943132),
#  ('Europeans', 0.04480533137987062),
#  ('Jewish', 0.04468035480713308),
#  ('liberal', 0.04446344838295921),
#  ('Republicans', 0.04436435681612938),
#  ('not', 0.04423680753974193),
#  ('American', 0.04400852403569648),
#  ('America', 0.04389053252476366),
#  ('Asians', 0.04372283594261719),
#  ('whites', 0.04344565937687312),
#  ('fuck', 0.04342742570720248),
#  ('President', 0.04257069366962029),
#  ('anti', 0.04231304087769386),
#  ('believe', 0.04218712907736202),
#  ('don', 0.04185606336972394),
#  ('terrorists', 0.041335017965871176),
#  ('Palestinians', 0.04090223849790769),
#  ('Asian', 0.039819251479525385),
#  ('gun', 0.03897034932732866),
#  ('Are', 0.0385025339345074),
#  ('castrated', 0.03842152906015456),
#  ('immigrants', 0.03833772933768037),
#  ('just', 0.03762416747584051),
#  ('ignorant', 0.036797888150329645),
#  ('Pakistanis', 0.036541496998276655),
#  ('African', 0.0356176475882092),
#  ('race', 0.03534725656984294),
#  ('guys', 0.035336348464515006),
#  ('Hindu', 0.035220420082522005),
#  ('Arabs', 0.035100813838025095),
#  ('Do', 0.03505450431350922),
#  ('fact', 0.03475499288176405),
#  ('democrats', 0.03442632656323725),
#  ('majority', 0.03438850149776933),
#  ('kill', 0.034111638033635934),
#  ('woman', 0.03408875656279948),
#  ('than', 0.03403465680845854),
#  ('guns', 0.03403139731896708),
#  ('terrorist', 0.03393983556501323),
#  ('shit', 0.03382652836247307),
#  ('penis', 0.03358927704369843),
#  ('White', 0.03346885625775136),
#  ('killing', 0.033193581509991445),
#  ('Liberals', 0.03308792093077238),
#  ('raped', 0.03307894234702517),
#  ('castrate', 0.03299103910040585),
#  ('dick', 0.03277514730417718),
#  ('ass', 0.03274710710425719),
#  ('dumb', 0.0326707396158981),
#  ('who', 0.03251443561967336),
#  ('Pakistani', 0.03245788849874313),
#  ('boys', 0.03241711930603128),
#  ('BJP', 0.0323614249393514),
#  ('racism', 0.032359174690039225),
#  ('ugly', 0.032246046405495096),
#  ('US', 0.03223247246077977),
#  ('gays', 0.03212919162308014),
#  ('sister', 0.032051222563443345),
#  ('Africans', 0.031988270927811334),
#  ('think', 0.03195926310279539),
#  ('God', 0.03195881094571042),
#  ('They', 0.031908402502837434),
#  ('Christian', 0.031819773002812926),
#  ('religion', 0.03175477842728717),
#  ('more', 0.031197604102090336),
#  ('fucking', 0.031107049140937204),
#  ('seem', 0.031054416988761765),
#  ('Pakistan', 0.030951597932085104),
#  ('claim', 0.030783300026890507),
#  ('true', 0.03045989216661382),
#  ('he', 0.030358563661789108),
#  ('blame', 0.03014466813777722),
#  ('superior', 0.03007783618248849),
#  ('idiots', 0.02997525000233137),
#  ('his', 0.02993038142621067),
#  ('leftists', 0.029781408290300647),
#  ('incest', 0.0292935446572032),
#  ('obsessed', 0.0290993838849291),
#  ('such', 0.02906581797941898),
#  ('Holocaust', 0.02895116447230446),
#  ('many', 0.02881832865410274),
#  ('males', 0.028695439062500102),
#  ('homosexuality', 0.028670132311677556),
#  ('homosexuals', 0.0285761016044445),
#  ('Turks', 0.028504659672315132),
#  ('killed', 0.028247419881260092),
#  ('man', 0.02824151797228532),
#  ('genocide', 0.028058384423467492),
#  ('sexual', 0.028003860600003785),
#  ('dont', 0.027880279701146884),
#  ('rights', 0.027732988229091666),
#  ('deny', 0.027693934965502667),
#  ('Russians', 0.02767924837436283),
#  ('Islamic', 0.027422321288602402),
#  ('crimes', 0.02731908129020251),
#  ('suck', 0.02726688777901772),
#  ('Brahmins', 0.02723470093844495),
#  ('children', 0.02717479610813194),
#  ('transgender', 0.02712561375144),
#  ('mom', 0.027041202703491567),
#  ('Hitler', 0.0269597791859562),
#  ('raping', 0.02695735674225852),
#  ('questions', 0.026850681873044503),
#  ('innocent', 0.026806575752760735),
#  ('support', 0.02678427769110339),
#  ('vote', 0.026696469095318677),
#  ('Isn', 0.026649636142536275),
#  ('Trumps', 0.026517152042378533),
#  ('president', 0.02650198655770992),
#  ('this', 0.026370059389169597),
#  ('Democrat', 0.02628813288596226),
#  ('homosexual', 0.02613364469739482),
#  ('country', 0.02605518507389613),
#  ('citizens', 0.026038012803573755),
#  ('pussy', 0.025989991830830714),
#  ('Jew', 0.025984942715579003),
#  ('Don', 0.02566551219661365),
#  ('propaganda', 0.025611478231719925),
#  ('Russian', 0.02561076441855318),
#  ('minorities', 0.02557694301824244),
#  ('Putin', 0.02554765762924703),
#  ('even', 0.025508850587114548),
#  ('Mexicans', 0.025455759923187892),
#  ('British', 0.025386243856863673),
#  ('Israelis', 0.025335984943941084),
#  ('countries', 0.025330914709749998),
#  ('like', 0.02532906137101273),
#  ('privilege', 0.025297612751177024),
#  ('Tamils', 0.025191375072791317),
#  ('‘', 0.02514777203705388),
#  ('religious', 0.02501691779198519),
#  ('Sikhs', 0.024924771321515816),
#  ('Since', 0.024919715894097763),
#  ('hatred', 0.02487465807582414),
#  ('ashamed', 0.024848082993675934),
#  ('world', 0.02483304793341101),
#  ('moderators', 0.024740745000522833),
#  ('as', 0.024700354783282797),
#  ('wing', 0.02469075113169771),
#  ('republicans', 0.02468117556122684),
#  ('terrorism', 0.02465521992411958),
#  ('Western', 0.024613092685370635),
#  ('destroy', 0.024536452079979627),
#  ('slaves', 0.024471124337616324),
#  ('conservative', 0.024401002425590755),
#  ('always', 0.024371257282779037),
#  ('feminist', 0.024289339943088177),
#  ('arrogant', 0.0242817786720908),
#  ('brainwashed', 0.0242732349153926),
#  ('Congress', 0.024257256019911085),
#  ('evil', 0.024079898986790027),
#  ('refugees', 0.023974248464834765),
#  ('racists', 0.023956671677577934),
#  ('Black', 0.023906366145253908),
#  ('admit', 0.0239032358239586),
#  ('trump', 0.023879343941049812),
#  ('Blacks', 0.023841569696752378),
#  ('leftist', 0.023830422897472364),
#  ('castration', 0.02377108890469351),
#  ('Mueller', 0.023753099626417147),
#  ('being', 0.02373496406018167),
#  ('ISIS', 0.023678501134365842),
#  ('fake', 0.023530132630754475),
#  ('Israeli', 0.023488436215701586),
#  ('towards', 0.023425514840709226),
#  ('IQ', 0.02339659060632733),
#  ('Barack', 0.0233281863509756),
#  ('Republican', 0.023300346555887252),
#  ('hell', 0.02310997906469405),
#  ('Nazis', 0.022937822567504682),
#  ('respect', 0.02283120182163277),
#  ('wives', 0.022805571536774878),
#  ('poor', 0.02267580843915819),
#  ('females', 0.022644360998626493),
#  ('slavery', 0.022566111371740454),
#  ('Canadians', 0.0224853132328611),
#  ('educated', 0.022433994118800784),
#  ('violent', 0.022412394152529384),
#  ('feminism', 0.022396968711374962),
#  ('lies', 0.02232379800820195),
#  ('North', 0.022263702846348387),
#  ('LGBT', 0.022260914201345704),
#  ('son', 0.022109547069910127),
#  ('Tamilians', 0.02200730907560252),
#  ('NRA', 0.0218540146040331),
#  ('atheist', 0.021841666033672325),
#  ('rapist', 0.021799578755104743),
#  ('Russia', 0.02174136328868291),
#  ('by', 0.021706843291561587),
#  ('South', 0.021647593517095286),
#  ('only', 0.021631560765920273),
#  ('voters', 0.021597387617002996),
#  ('Palestinian', 0.021565946811742582),
#  ('freedom', 0.021552289942440333),
#  ('accept', 0.021540978291614384),
#  ('shootings', 0.02150941929299325),
#  ('here', 0.021506004261839632),
#  ('victims', 0.021501278790367943),
#  ('Democratic', 0.02149635534936373),
#  ('sexist', 0.02140750368362927),
#  ('illegal', 0.02139789778739348),
#  ('marry', 0.021372680973215617),
#  ('shithole', 0.021285212552256797),
#  ('then', 0.02128301358400837),
#  ('Women', 0.02127312870709716),
#  ('sexually', 0.021263371883474512),
#  ('own', 0.021238457773624618),
#  ('these', 0.02123056753355297),
#  ('hypocritical', 0.021172268526726542),
#  ('bullshit', 0.021171699317265376),
#  ('inferior', 0.021116901087154433),
#  ('Dalits', 0.02108624944967351),
#  ('abortion', 0.02105098346791004),
#  ('cousin', 0.020959595141391747),
#  ('idiot', 0.020923557519469813),
#  ('hypocrisy', 0.02089173081284517),
#  ('minority', 0.020870023249030284),
#  ('Whites', 0.020847000078698205),
#  ('voted', 0.020749694637293748),
#  ('Bengalis', 0.02070000864166998),
#  ('hateful', 0.020653237470615107),
#  ('cock', 0.02059581010640565),
#  ('Koreans', 0.020594608987140064),
#  ('Party', 0.020564135134717353),
#  ('say', 0.02055421547272011),
#  ('supporting', 0.02055382528014843),
#  ('aren', 0.0204987757460524),
#  ('murder', 0.020498700961521447),
#  ('violence', 0.02046201853506254),
#  ('USA', 0.02037447828783287),
#  ('wrong', 0.02035238086349299),
#  ('slave', 0.0203335624862386),
#  ('democratic', 0.020315546452613024),
#  ('daughter', 0.02031501892189532),
#  ('races', 0.020265093736710302),
#  ('right', 0.020212365634959897),
#  ('shooting', 0.02008404478704098),
#  ('agree', 0.020060223191682033),
#  ('trolls', 0.02004490004075813),
#  ('Arab', 0.020037195379388535),
#  ('China', 0.020029542062545265),
#  ('assholes', 0.019989526172714323),
#  ('nation', 0.019973327972002623),
#  ('hypocrites', 0.019937268402155733),
#  ('Germans', 0.01990998945260776),
#  ('other', 0.01986760047700319),
#  ('asshole', 0.019861755872369363),
#  ('Jesus', 0.019774119392845266),
#  ('PM', 0.019764344036995323),
#  ('theists', 0.019761669309416495),
#  ('Allah', 0.01974937919523343),
#  ('pretend', 0.01974463754876492),
#  ('since', 0.019703958578320087),
#  ('Iranians', 0.01969108501263057),
#  ('government', 0.019677852349207315),
#  ('Nazi', 0.019645871075359554),
#  ('skinned', 0.019620048696197382),
#  ('East', 0.019593493151579322),
#  ('Japanese', 0.019591436069984557),
#  ('proud', 0.019576730676518828),
#  ('losers', 0.01954460744148603),
#  ('offended', 0.01950501690658041),
#  ('rapists', 0.01946429339155668),
#  ('complain', 0.019427996113473688),
#  ('Kannadigas', 0.019417073687170085),
#  ('her', 0.019412294345167638),
#  ('holocaust', 0.019407888007228393),
#  ('illiterate', 0.01937689019077781),
#  ('pro', 0.01936863137384723),
#  ('lie', 0.019259902604879538),
#  ('West', 0.01920954294834767),
#  ('Kurds', 0.01917787193782387),
#  ('ban', 0.01915215953189562),
#  ('Amendment', 0.01909571258080483),
#  ('Indonesians', 0.01908617843229366),
#  ('Palestine', 0.018966559074978163),
#  ('thousands', 0.01896261073798024),
#  ('Westerners', 0.018906134982379856),
#  ('Muhammad', 0.018885567227230983),
#  ('troll', 0.018850592887595802),
#  ('Melania', 0.01884313191193772),
#  ('want', 0.018796054897695594),
#  ('murdered', 0.018738962193102324),
#  ('him', 0.018725759548397853),
#  ('husbands', 0.018724133549879653),
#  ('moron', 0.018710409566660972),
#  ('those', 0.01861244650219456),
#  ('corrupt', 0.01852965824641721),
#  ('Kashmiri', 0.018492350668593113),
#  ('everyone', 0.018455657138784158),
#  ('FBI', 0.018419736374199042),
#  ('worship', 0.01839144118229829),
#  ('deport', 0.018387045370547615),
#  ('nonsense', 0.018378759764659462),
#  ('election', 0.01837089552055227),
#  ('lesbians', 0.018370261895367893),
#  ('politicians', 0.018369801215305653),
#  ('Europe', 0.01836944468573783),
#  ('god', 0.018312972510710696),
#  ('Isnt', 0.01830606998163878),
#  ('calling', 0.018303301432204534),
#  ('deserve', 0.018294272255849165),
#  ('collusion', 0.018270913123250118),
#  ('GOP', 0.018262926100519876),
#  ('intolerant', 0.018257688379043298),
#  ('destroying', 0.018197221899690107),
#  ('nothing', 0.01819619375072308),
#  ('progressives', 0.018157883170464368),
#  ('Jinping', 0.018146474088529083),
#  ('bitch', 0.018126192623470556),
#  ('care', 0.01809556407709218),
#  ('male', 0.01807626284591878),
#  ('Did', 0.018061211650690058),
#  ('penises', 0.01803643846362405),
#  ('gender', 0.018030213593574165),
#  ('rude', 0.018013602372516892),
#  ('cant', 0.01790376035308801),
#  ('Conservatives', 0.01789070708417578),
#  ('discriminate', 0.017869596032746078),
#  ('uneducated', 0.017866168423555564),
#  ('act', 0.017864139743616104),
#  ('RSS', 0.017813697743901253),
#  ('Australians', 0.017783449660719073),
#  ('lazy', 0.017740918100925124),
#  ('about', 0.017724740948390574),
#  ('Stormy', 0.01769778588511023),
#  ('left', 0.01767942794239967),
#  ('biased', 0.017677040446627906),
#  ('illegals', 0.017667056869815637),
#  ('civilians', 0.017632341450202305),
#  ('crap', 0.017628607831002743),
#  ('Filipinos', 0.017602714336373487),
#  ('Hispanics', 0.017596077993837125),
#  ('Left', 0.017586204455100295),
#  ('Zionist', 0.017568044967915773),
#  ('minded', 0.017530939806960157),
#  ('streets', 0.017529802602216638),
#  ('atheism', 0.017514193363401962),
#  ('aping', 0.01748428021582595),
#  ('when', 0.017481776312497966),
#  ('European', 0.017465435400249682),
#  ('equality', 0.017439642950646532),
#  ('Brits', 0.01740728496542166),
#  ('bhakts', 0.017403816190097274),
#  ('obvious', 0.01735005067249889),
#  ('no', 0.017311503232113973),
#  ('supremacists', 0.01727201058758509),
#  ('jew', 0.01726931338105054),
#  ('radical', 0.017262951431658007),
#  ('millions', 0.01722090708596794),
#  ('but', 0.017176836153299263),
#  ('nationalists', 0.017170689610182373),
#  ('It', 0.017106723158081608),
#  ('Latinos', 0.01710452382554469),
#  ('fucked', 0.01699239788812674),
#  ('allow', 0.016988351358258272),
#  ('mothers', 0.016979263759069264),
#  ('boobs', 0.01695908208954447),
#  ('western', 0.016943377781537483),
#  ('racial', 0.016928936445915206),
#  ('Narendra', 0.01691523032611962),
#  ('claiming', 0.016863647438679193),
#  ('SJWs', 0.01685886296391779),
#  ('defend', 0.01684015667709374),
#  ('Italians', 0.016839405266837304),
#  ('trying', 0.016821238761141513),
#  ('Christianity', 0.016816431000503215),
#  ('especially', 0.016808258288883392),
#  ('finally', 0.01674876387788629),
#  ('Greeks', 0.016666303548566203),
#  ('aunt', 0.016626222734501015),
#  ('muslims', 0.016606300045280256),
#  ('atrocities', 0.01659737973688932),
#  ('dicks', 0.016580507003545582),
#  ('Iran', 0.01656438924861667),
#  ('insist', 0.016528799618568495),
#  ('Bangladeshis', 0.016473026752136133),
#  ('criminals', 0.016431509798467456),
#  ('ethnic', 0.016421318388597384),
#  ('non', 0.01641695921819363),
#  ('understand', 0.016345931283620385),
#  ('realise', 0.016320027391099633),
#  ('shame', 0.016312278593546482),
#  ('vagina', 0.016291343955407166),
#  ('yet', 0.01628046136953144),
#  ('Aren', 0.016224229071502127),
#  ('bigoted', 0.016223768756771256),
#  ('culture', 0.016188521900417575),
#  ('Catholics', 0.01617033385897403),
#  ('agenda', 0.016111907538601818),
#  ('enslaved', 0.016087939712531526),
#  ('shameless', 0.01607358912553063),
#  ('rapes', 0.016073193114000305),
#  ('every', 0.01604827870364839),
#  ('mother', 0.016045931759283105),
#  ('media', 0.016043994851972738),
#  ('asking', 0.016008467267608836),
#  ('virgins', 0.015996048700589675),
#  ('Malays', 0.015995664658383254),
#  ('murdering', 0.015995664658383254),
#  ('called', 0.015993650647987693),
#  ('attacking', 0.015980554986450325),
#  ('simply', 0.015961947720222858),
#  ('blindly', 0.015950413115583057),
#  ('accuse', 0.01590312265922202),
#  ('trans', 0.015900868074065065),
#  ('Zionists', 0.015852539575917465),
#  ('folks', 0.015809737677029218),
#  ('vegans', 0.01579990147108223),
#  ('idiotic', 0.015799257973085522),
#  ('criticize', 0.01578885018933137),
#  ('she', 0.015776790494031728),
#  ('secular', 0.015761420142795118),
#  ('denying', 0.01575269403932026),
#  ('okay', 0.015751097909091363),
#  ('pedophile', 0.015669953401437817),
#  ('evidence', 0.015639630050514382),
#  ('fascist', 0.015617882303240209),
#  ('Vietnamese', 0.015609459873585443),
#  ('call', 0.015598874480044784),
#  ('Fuck', 0.015538046744454139),
#  ('Kim', 0.015523518645360827),
#  ('civilized', 0.015499224357139811),
#  ('instead', 0.015444722268122539),
#  ('ancestors', 0.015442357662133296),
#  ('clearly', 0.01543820413191267),
#  ('Bengali', 0.015435123741917337),
#  ('immigration', 0.015430319643400778),
#  ('punish', 0.0154294723777767),
#  ('leaders', 0.015427513379635003),
#  ('Dont', 0.015372043274546984),
#  ('acknowledge', 0.015370884923275659),
#  ('fool', 0.015350113850482903),
#  ('seduce', 0.015347481598130255),
#  ('theyre', 0.015304021455121476),
#  ('morons', 0.015301243737063666),
#  ('Tamil', 0.015292665002279757),
#  ('lesbian', 0.015290225644508092),
#  ('tolerate', 0.015288435983719453),
#  ('intelligent', 0.0152735300732544),
#  ('jealous', 0.015269532751706989),
#  ('bombing', 0.015263269672181964),
#  ('attack', 0.015262412743370701),
#  ('hated', 0.01522230741885851),
#  ('pedophilia', 0.01519976992527033),
#  ('Syria', 0.015175675080887054),
#  ('have', 0.015158247053736345),
#  ('truth', 0.015150618068983322),
#  ('peace', 0.015150316902630382),
#  ('elect', 0.015127692333265517),
#  ('cowards', 0.015124604250298207),
#  ('Bhakts', 0.015115306364961605),
#  ('allowed', 0.015109893613653037),
#  ('Jong', 0.01508329617785649),
#  ('communist', 0.015076815611659395),
#  ('population', 0.015069988351032402),
#  ('blind', 0.015051447849015801),
#  ('Kashmir', 0.015037668422957328),
#  ('barbaric', 0.014994672801874763),
#  ('refuse', 0.014947144552056561),
#  ('false', 0.014933869036190052),
#  ('daughters', 0.014920030378277417),
#  ('condemn', 0.014917131132490173),
#  ('wingers', 0.01489651289621814),
#  ('spreading', 0.014893328025202117),
#  ('with', 0.014854992617352281),
#  ('Sanders', 0.014843644600831433),
#  ('bitches', 0.014812935844036692),
#  ('homophobic', 0.014805274887226764),
#  ('Quorans', 0.014799551508593098),
#  ('masturbate', 0.01479350365856557),
#  ('dirty', 0.014790095488751464),
#  ('filthy', 0.014778304622444402),
#  ('disgusting', 0.014770879541883308),
#  ('Jerusalem', 0.01469458501221331),
#  ('nations', 0.014681946020698698),
#  ('Native', 0.014649274354803968),
#  ('babies', 0.014641202231638055),
#  ('bunch', 0.01464072967469696),
#  ('insult', 0.014608064536887637),
#  ('Xi', 0.01459777825270564),
#  ('Now', 0.014566772764081427),
#  ('Gandhi', 0.014537544751635378),
#  ('bigots', 0.014497844786475981),
#  ('abortions', 0.014481840722675257),
#  ('pathetic', 0.01445460148269204),
#  ('Zealanders', 0.014450444778255288),
#  ('migrants', 0.014429803778050074),
#  ('Mormons', 0.014392565832269574),
#  ('haters', 0.014377297874495057),
#  ('seems', 0.014371883267261281),
#  ('sisters', 0.014352268681063696),
#  ('Lives', 0.014328595670521754),
#  ('north', 0.014327097326330092),
#  ('steal', 0.01432477960805223),
#  ('Semitic', 0.01431166678427829),
#  ('Daniels', 0.014307615292384081),
#  ('committed', 0.014302651895235613),
#  ('terror', 0.014297060198551181),
#  ('crime', 0.014261905586139888),
#  ('deaths', 0.014242652484863835),
#  ('evangelicals', 0.014216936713204455),
#  ('tend', 0.014180387323346207),
#  ('Sharia', 0.01417094689529964),
#  ('cheat', 0.01416842828639482),
#  ('worse', 0.01413963194043942),
#  ('supremacy', 0.014127200320798105),
#  ('dislike', 0.014090622090453362),
#  ('People', 0.014087015031200733),
#  ('murders', 0.014082403135530655),
#  ('million', 0.01407549722813751),
#  ('SJW', 0.014059845822266126),
#  ('sons', 0.014058306394172626),
#  ('fools', 0.014056221776293131),
#  ('unattractive', 0.014049382724659241),
#  ('oppressed', 0.014043485096903945),
#  ('cunt', 0.014005634238857366),
#  ('us', 0.013981983468650209),
#  ('protest', 0.013978944994544943),
#  ('bashing', 0.013950199383562201),
#  ('assault', 0.013916836303832853),
#  ('religions', 0.013906071685258266),
#  ('Caucasians', 0.013904348905973538),
#  ('really', 0.013897332446833294),
#  ('Rohingya', 0.013896752105965512),
#  ('politically', 0.013882717083716713),
#  ('it', 0.013877924687065574),
#  ('pride', 0.013876893858334682),
#  ('believers', 0.013845245270307876),
#  ('denial', 0.013817617669925591),
#  ('justify', 0.013794232775261147),
#  ('lying', 0.013788625262196125),
#  ('hating', 0.013784422256810059),
#  ('commit', 0.013759666474507715),
#  ('traitor', 0.013753757152781067),
#  ('cops', 0.01375033682000963),
#  ('delusional', 0.013744885947145773),
#  ('westerners', 0.013744885947145773),
#  ('Shouldn', 0.0137023952119955),
#  ('IQs', 0.013696466660564798),
#  ('saying', 0.013695083149755373),
#  ('testicles', 0.013662419507604088),
#  ('Bill', 0.013659464159068185),
#  ('killings', 0.013657553682675754),
#  ('female', 0.01365700048753698),
#  ('oppose', 0.01364118878914254),
#  ('harass', 0.013629590478399931),
#  ('Middle', 0.013605730934974147),
#  ('moderation', 0.013591392171270006),
#  ('un', 0.01357126097753046),
#  ('kick', 0.013571133920466182),
#  ('illegally', 0.013569361330396493),
#  ('Girls', 0.013561926698049346),
#  ('indians', 0.013558987208831273),
#  ('Clintons', 0.013522761460769172),
#  ('backward', 0.01351806849697913),
#  ('aunty', 0.013510543082972917),
#  ('lack', 0.013495207413968138),
#  ('Matter', 0.013488006971329188),
#  ('CNN', 0.013487338697145983),
#  ('butt', 0.01346757661723859),
#  ('patriotic', 0.013454307934467995),
#  ('Ashkenazi', 0.01345303108545778),
#  ('kids', 0.01343243102556318),
#  ('superiority', 0.013425970304414349),
#  ('OK', 0.013420508207321257),
#  ('forced', 0.013418232933812266),
#  ('mostly', 0.013409969095955841),
#  ('pedophiles', 0.013399566379960592),
#  ('If', 0.013389181980143121),
#  ('smarter', 0.013369371793685535),
#  ('traitors', 0.013358011812555895),
#  ('Obamas', 0.013358011812555895),
#  ('States', 0.013333039832156062),
#  ('extremist', 0.013327531056729966),
#  ('try', 0.013313167381683231),
#  ('Malaysians', 0.013288091860537893),
#  ('brainwashing', 0.013279152239128221),
#  ('Brahmin', 0.013278876787761143),
#  ('ra', 0.013278481994827113),
#  ('crazy', 0.013241189573166801),
#  ('society', 0.013239370919136385),
#  ('damn', 0.013229630231514697),
#  ('himself', 0.013211725176052234),
#  ('Bernie', 0.013192978812108467),
#  ('Prince', 0.01319156067128457),
#  ('etc', 0.013177198167037815),
#  ('immoral', 0.013173802707618906),
#  ('foreigners', 0.013160830611476333),
#  ('incompetent', 0.013138743387332497),
#  ('Bush', 0.013127426505917588),
#  ('POTUS', 0.013121832428637585),
#  ('Brazilians', 0.013113018412950617),
#  ('genders', 0.013103970964740827),
#  ('Taiwanese', 0.013086132330554024),
#  ('south', 0.013082451288819378),
#  ('Men', 0.013061775221634306),
#  ('secretly', 0.013050800461591322),
#  ('supporter', 0.013025289699566752),
#  ('castrating', 0.013007194443587765),
#  ('activists', 0.013001723603258374),
#  ('trash', 0.01296165133590392),
#  ('despite', 0.012945615624249136),
#  ('Shias', 0.01294162111369073),
#  ('outrage', 0.012929406335503137),
#  ('Bible', 0.012926543421879317),
#  ('Kashmiris', 0.012918389977766677),
#  ('xenophobic', 0.012904794939491548),
#  ('tits', 0.012897432948423658),
#  ('ignore', 0.012894475205306422),
#  ('Trudeau', 0.0128908011950642),
#  ('liberalism', 0.012872947849795124),
#  ('complaining', 0.012872947849795124),
#  ('party', 0.012841868431482968),
#  ('stupidity', 0.01283413740175047),
#  ('DNC', 0.01283413740175047),
#  ('Mao', 0.012820535802713333),
#  ('Punjabis', 0.012813908787552598),
#  ('dictator', 0.012800772441494931),
#  ('aware', 0.012800206859009887),
#  ('childish', 0.012792762996514327),
#  ('ignorance', 0.012776406532179145),
#  ('Hinduism', 0.012758210463134334),
#  ('Sikh', 0.012757469349381788),
#  ('Jehovah', 0.012757066318820684),
#  ('tolerant', 0.012756668641729094),
#  ('Atheists', 0.012729512230773713),
#  ('Serbs', 0.012727329589999808),
#  ('treason', 0.01272494001446186),
#  ('democracy', 0.012721066545151),
#  ('FYROM', 0.01271586837041903),
#  ('consensual', 0.012707451631203967),
#  ('claims', 0.012701017032910366),
#  ('enslave', 0.012684907533781467),
#  ('muslim', 0.012644004078988297),
#  ('massacred', 0.012638474465217967),
#  ('regime', 0.01263320091414403),
#  ('flat', 0.012632974125508956),
#  ('Anti', 0.012605553974213313),
#  ('straight', 0.012593539831264157),
#  ('elected', 0.01259344474548086),
#  ('attractive', 0.01257480532892971),
#  ('insulting', 0.012574122954274338),
#  ('attracted', 0.012569248562977257),
#  ('allowing', 0.01256546190004761),
#  ('murderers', 0.012545409022365813),
#  ('prophet', 0.012526378528458514),
#  ('Hispanic', 0.012525362403561115),
#  ('Michelle', 0.012525240875227866),
#  ('generally', 0.012504307836841857),
#  ('Meghan', 0.012492579010574965),
#  ('Rahul', 0.012491939986909915),
#  ('arent', 0.012490405723375645),
#  ('liar', 0.01248971380331683),
#  ('blaming', 0.012477598931694232),
#  ('bigotry', 0.012477475499547074),
#  ('snowflakes', 0.012473513487491409),
#  ('whores', 0.012454468417167429),
#  ('brainwash', 0.01245058371143857),
#  ('unborn', 0.012446905180867348),
#  ('caste', 0.0124295064996728),
#  ('Islamists', 0.012422483729003446),
#  ('illogical', 0.012408593590136711),
#  ('autistic', 0.01240600471662739),
#  ('Liberal', 0.012391742000106176),
#  ('LGBTQ', 0.012391742000106176),
#  ('liars', 0.01236783049729458),
#  ('torture', 0.012351375921686536),
#  ('prostitutes', 0.012329154141098973),
#  ('privileged', 0.012323454039267752),
#  ('lives', 0.012317459306486459),
#  ('greedy', 0.0122855223379215),
#  ('cult', 0.012285292390235996),
#  ('border', 0.012265075800339649),
#  ('isn', 0.012263548457442076),
#  ('control', 0.012233779859144735),
#  ('sluts', 0.012220575076040279),
#  ('lick', 0.012194691902038587),
#  ('sucking', 0.01219447286590714),
#  ('Quran', 0.012182299283564405),
#  ('angry', 0.012176851910661805),
#  ('obese', 0.012175257648153578),
#  ('perverts', 0.012163935119215569),
#  ('camps', 0.012157708895368604),
#  ('Troll', 0.012156655976404362),
#  ('assume', 0.012151453490876775),
#  ('believing', 0.01213706199203008),
#  ('Mr', 0.012136593823062721),
#  ('marrying', 0.012128951950710704),
#  ('come', 0.012111477701210138),
#  ('slut', 0.012109671001116169),
#  ('bigot', 0.012098610586136028),
#  ('community', 0.01209609145497878),
#  ('scum', 0.012094724786009519),
#  ('peoples', 0.012087493581934276),
#  ('supremacist', 0.012087142412804829),
#  ('communists', 0.0120798089425537),
#  ('arabs', 0.012078853343783632),
#  ('United', 0.012065887788194033),
#  ('Shabbat', 0.01204223203549127),
#  ('welfare', 0.012035919327563697),
#  ('apartheid', 0.012007907599613949),
#  ('toward', 0.011994756853035603),
#  ('Slavs', 0.011977301280740312),
#  ('cow', 0.011936166281399124),
#  ('slap', 0.011926820695246873),
#  ('Hussein', 0.01191287811331972),
#  ('protesting', 0.01189531665172979),
#  ('Sunni', 0.011883091882814107),
#  ('This', 0.011878323635280899),
#  ('unarmed', 0.011861862556433135),
#  ('misogynistic', 0.011856048291372762),
#  ('perverted', 0.011856048291372762),
#  ('attacks', 0.011832993761917321),
#  ('electing', 0.011824373435604257),
#  ('openly', 0.011817308262712736),
#  ('Hamas', 0.011799114862362172),
#  ('disrespect', 0.011782158766159302),
#  ('Merkel', 0.011782158766159302),
#  ('infidels', 0.011781340799454497),
#  ('Sunnis', 0.011767539846111506),
#  ('defending', 0.011762632946584339),
#  ('pretending', 0.011761050885301265),
#  ('cruel', 0.011727228641949444),
#  ('Caucasian', 0.011722462479681816),
#  ('advocates', 0.011721834653062283),
#  ('Macedonians', 0.011711054954343268),
#  ('brothers', 0.011710132110673033),
#  ('apist', 0.011702543001126513),
#  ('Racist', 0.011694448704214065),
#  ('born', 0.01168390781453343),
#  ('News', 0.01168048658097744),
#  ('heterosexual', 0.011680278577900736),
#  ('jihad', 0.011649601919455943),
#  ('mainland', 0.011649028608671647),
#  ('Kurdish', 0.011638065389460286),
#  ('Britain', 0.011636549579453348),
#  ('shouldn', 0.011636069427329544),
#  ('Ivanka', 0.011631266819592404),
#  ('peaceful', 0.011618168134976702),
#  ('ridiculous', 0.011611211666262368),
#  ('Biharis', 0.011574683105278634),
#  ('genitals', 0.011567241236105336),
#  ('despise', 0.011566847614553904),
#  ('missionaries', 0.01155700278306579),
#  ('selfish', 0.011548464858134416),
#  ('behave', 0.011547390999524799),
#  ('Doesn', 0.011538169396287996),
#  ('fair', 0.011531101773409616),
#  ('discrimination', 0.011511755948426978),
#  ('massacre', 0.011508389794258748),
#  ('abuse', 0.011508025350126589),
#  ('Moderation', 0.011497762449645678),
#  ('Kejriwal', 0.011493184999289622),
#  ('mad', 0.011470170079599742),
#  ('fascists', 0.01145872204176675),
#  ('mentally', 0.011386658736692786),
#  ('investigation', 0.011383398644379627),
#  ('Macedonia', 0.011373323612864332),
#  ('cunts', 0.01137159803154098),
#  ('Dems', 0.011365743868669056),
#  ('voting', 0.01136167794527235),
#  ('naked', 0.011359965322383193),
#  ('Turkish', 0.01135186878097024),
#  ('fat', 0.011344293604419213),
#  ('belief', 0.011329761530580015),
#  ('war', 0.011328010001134514),
#  ('Pelosi', 0.011305209493674839),
#  ('tyranny', 0.011298865852689379),
#  ('extremists', 0.011297347835045244),
#  ('useless', 0.011283270050678609),
#  ('oppressive', 0.011280351033362114),
#  ('families', 0.011262974252352414),
#  ('murderer', 0.011234000510310316),
#  ('Most', 0.0112329772847304),
#  ('Mormon', 0.011231883722810946),
#  ('So', 0.011229757962573843),
#  ('acceptable', 0.011225005079663989),
#  ('retarded', 0.011221134219637918),
#  ('beautiful', 0.011220014993469404),
#  ('young', 0.011212947538944067),
#  ('Swedes', 0.0112024863762639),
#  ('groups', 0.011195154441463526),
#  ('nasty', 0.01117469279420606),
#  ('dumber', 0.011168047133502845),
#  ('puppet', 0.011165150970959749),
#  ('entitled', 0.011163423656407412),
#  ('hoax', 0.011146739688062313),
#  ('democrat', 0.011109142167113955),
#  ('Markle', 0.011100107045826216),
#  ('THEY', 0.011072209880173928),
#  ('evolutionists', 0.011072209880173928),
#  ('Benghazi', 0.01107152141127847),
#  ('poop', 0.0110495334668121),
#  ('slaughtered', 0.01104799251869842),
#  ('aggressive', 0.011042127110399971),
#  ('Buddhists', 0.011038261871983718),
#  ('everybody', 0.011031149765140271),
#  ('Irish', 0.011008432947012085),
#  ('let', 0.01100753834538156),
#  ('molest', 0.010999897546792887),
#  ('fellow', 0.010986590385469347),
#  ('demonize', 0.010980349631239094),
#  ('WHY', 0.010977998595449734),
#  ('whore', 0.010965140854481768),
#  ('down', 0.010897324475949563),
#  ('Alabamians', 0.010895471228356554),
#  ('votes', 0.010890440595394055),
#  ('forcibly', 0.010889395348733398),
#  ('Adolf', 0.010882741258496701),
#  ('stealing', 0.010877621688249078),
#  ('Was', 0.010872563008817566),
#  ('That', 0.01085427074148256),
#  ('threat', 0.010849180405200934),
#  ('dishonest', 0.010826337330265858),
#  ('Nibiru', 0.010821801882646366),
#  ('Dalit', 0.010820922635915843),
#  ('Christ', 0.01080435054221608),
#  ('desperate', 0.01076600788541565),
#  ('oppress', 0.010759356186348797),
#  ('Marathis', 0.010755507694580934),
#  ('Jabba', 0.010750097409918719),
#  ('southern', 0.01072575541118446),
#  ('hillary', 0.010706891262153127),
#  ('sexism', 0.01070238950689738),
#  ('oppression', 0.010683377275121936),
#  ('FUCK', 0.010678998775833365),
#  ('priests', 0.010677177468824288),
#  ('dominated', 0.01066960862084748),
#  ('afraid', 0.010666051358719666),
#  ('Mexican', 0.01065670988156492),
#  ('indian', 0.010651657904175509),
#  ('unlike', 0.010650269286015956),
#  ('Ukrainians', 0.010647251339197198),
#  ('affirmative', 0.01062608504034066),
#  ('persecuted', 0.01062270908819872),
#  ('Latino', 0.01062270908819872),
#  ('genocides', 0.010621798564953443),
#  ('though', 0.010621245080025498),
#  ('spread', 0.010605156456117691),
#  ('panties', 0.010589156527383023),
#  ('kicked', 0.010589156527383023),
#  ('responsible', 0.01057888864096137),
#  ('erect', 0.010578631112284213),
#  ('intellectual', 0.01056343536243263),
#  ('everywhere', 0.010562380213081188),
#  ('coward', 0.010560155648819786),
#  ('loot', 0.010557435387694021),
#  ('cum', 0.01055248856830518),
#  ('Weinstein', 0.010551821250896404),
#  ('womens', 0.010550054655989252),
#  ('uglier', 0.010529986832058712),
#  ('apologize', 0.010522231990643116),
#  ('horny', 0.01051914209819293),
#  ('jail', 0.0105154969181566),
#  ('pussies', 0.010477763687794258),
#  ('slaughter', 0.010476120393896013),
#  ('ask', 0.010468674260397638),
#  ('Tennesseans', 0.010465660867502407),
#  ('gypsies', 0.01046516219054373),
#  ('Witnesses', 0.01045423558729636),
#  ('shitty', 0.010443224008203238),
#  ('Sweden', 0.010432026838555892),
#  ('piss', 0.01043008721255437),
#  ('ideology', 0.01042601768520192),
#  ('treasonous', 0.01040715550097162),
#  ('Doesnt', 0.010406912165910016),
#  ('forcing', 0.010404939789728266),
#  ('speak', 0.01040091492062025),
#  ('Gaza', 0.010388755954794137),
#  ('destroyed', 0.010386843274661831),
#  ('shoot', 0.010379881369215568),
#  ('insane', 0.010377257280771953),
#  ('wipe', 0.010361814893774116),
#  ('Satan', 0.010356002143381173),
#  ('TRUMP', 0.010352418499376539),
#  ('naive', 0.010344400870208582),
#  ('brutal', 0.01034389159043158),
#  ('borders', 0.010342678044487696),
#  ('ones', 0.01033726940502363),
#  ('Iraq', 0.010334846710120861),
#  ('Soros', 0.010334255312403172),
#  ('dossier', 0.010322525167761866),
#  ('smug', 0.010319734142002476),
#  ('old', 0.010317866904856166),
#  ('whining', 0.010317106227490713),
#  ('Drumpf', 0.010316124155853264),
#  ('nonwhites', 0.010316124155853264),
#  ('fanatics', 0.010314233319795222),
#  ('over', 0.01031401203408832),
#  ('argue', 0.010305703062977454),
#  ('obviously', 0.010289482416217589),
#  ('excuse', 0.010276377517979857),
#  ('censor', 0.01026993591963612),
#  ('jerks', 0.01026993591963612),
#  ('McCain', 0.010262157047740401),
#  ('racially', 0.010262157047740401),
#  ('news', 0.01026108312602852),
#  ('Prophet', 0.01025183590938217),
#  ('intellectuals', 0.010250415845434192),
#  ('Singaporeans', 0.010239328866418713),
#  ('conspiracy', 0.01022625670455906),
#  ('faith', 0.01022617017117493),
#  ('Iranian', 0.010222947385519135),
#  ('usury', 0.010215819174265714),
#  ('inane', 0.010215819174265714),
#  ('beliefs', 0.010210102914483588),
#  ('question', 0.010209824008223015),
#  ('socialist', 0.010207113036787011),
#  ('nigger', 0.010198734374723217),
#  ('adultery', 0.01019414207519307),
#  ('homeland', 0.01019414207519307),
#  ('ill', 0.010193737785194574),
#  ('fathers', 0.010192013212274179),
#  ('morals', 0.010177362876831205),
#  ('foolish', 0.010170778503484445),
#  ('KKK', 0.010167139790928115),
#  ('vile', 0.010166671688259401),
#  ('Han', 0.010152217085140516),
#  ('Islamophobic', 0.010126008899778481),
#  ('Leftists', 0.010126008899778481),
#  ('police', 0.010124182623802935),
#  ('bestiality', 0.010118434077842365),
#  ('promiscuous', 0.01011465649724513),
#  ('bash', 0.010091681553386416),
#  ('progressive', 0.010089501204911753),
#  ('Hindi', 0.010086663373378707),
#  ('silly', 0.010081779587605864),
#  ('deranged', 0.010081126170641906),
#  ('Surely', 0.010065852737703116),
#  ('UK', 0.010063983884299618),
#  ('hostile', 0.010056111756124166),
#  ('Mohajirs', 0.010048097962279427),
#  ('Rohingyas', 0.010033053309284652),
#  ('regressive', 0.010024536609250095),
#  ('anus', 0.010019326912790203),
#  ('criminal', 0.010015717616445693),
#  ('Judaism', 0.009995728346184183),
#  ('Netanyahu', 0.009994594631925756),
#  ('re', 0.009977342999565571),
#  ('aunties', 0.009968160005280608),
#  ('groping', 0.009968160005280608),
#  ('inferiors', 0.00994717255818094),
#  ('campaign', 0.009942242530896374),
#  ('asinine', 0.009939825841724129),
#  ('Hillarys', 0.009939825841724129),
#  ('spermatic', 0.009939825841724129),
#  ('Turkey', 0.009932274037900151),
#  ('trolling', 0.0099295211237105),
#  ('labeled', 0.009907612523140492),
#  ('reparations', 0.009906494621002378),
#  ...]
